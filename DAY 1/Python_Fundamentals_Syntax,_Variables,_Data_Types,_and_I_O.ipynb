# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ak-lilly/NASSCOM/blob/main/DAY%201/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Alice"
age = 25
height = 5.6

# Print values
print("Name:", name)
print("Age:", age)
print("Height:", height)
# Out:
# Name: Alice
# Age: 25
# Height: 5.6

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
# String
c = "Python"
print(type(c))

# Boolean
d = True
print(type(d))

# List
e = [1, 2, 3, "four"]
print(type(e), e)

# Dictionary
f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
print("Welcome to Python I/O!")
# Out:
# Welcome to Python I/O!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: SARVANI
# Hello, SARVANI

# %%
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 17
# You will be 18 next year.
